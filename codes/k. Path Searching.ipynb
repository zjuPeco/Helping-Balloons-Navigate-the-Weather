# %% [markdown]
# # 1. Import all the packages we need

# %%
import pickle
import numpy as np
import os
import re
import json
import pandas as pd
from Ant import Ant

# %% [markdown]
# # 2. Run the following code to make sure all the functions can work

# %%
def compute_distance2(start_x, start_y, tar_x, tar_y):
    """
    compute the distance between two points
    """
    return 2 * (abs(start_x - tar_x) + abs(start_y - tar_y))

def compute_distance3(start_x, start_y, mid_x, mid_y, tar_x, tar_y):
    """
    compute the distance between three points
    """
    dis1 = 2 * (abs(start_x - mid_x) + abs(start_y - mid_y))
    dis2 = 2 * (abs(mid_x - tar_x) + abs(mid_y - tar_y))
    return (dis1, dis2, dis1 + dis2)

def get_path(points, stay_time, wind_matrix, rain_matrix, wind_threshold, rain_threshold):
    """
    get the path at the guide of points and stay time
    
    points -- guide points to help the Ant find the path
    stay_time -- stay time at each point, mostly used to change the take-off time of the plane
    wind_matrix -- all the wind value at each point. Shape: (548, 421, 18)
    rain_matrix -- all the rainfall value at each point. Shape: (548, 421, 18)
    wind_threshold -- wind threshold at each segment path
    rain_threshold -- rain threshold at each segment path
    """
    if (len(points) != len(stay_time)):
        raise Exception("the length of points and stay_time must be equal")
    
    if (len(points) < 2):
        raise Exception("the length of points or stay_time should be bigger than 1")
    
    dis = 0
    path = [points[0]]
    for p_index in range(len(points) - 1):
        # stay at one poinst
        dis += stay_time[p_index]
        path = path + [points[p_index]] * (stay_time[p_index] // 2)
        print ('point {}: stay for {} min'.format(points[p_index], stay_time[p_index]))
        
        # shortest path
        ant = Ant(points[p_index][0], points[p_index][1], points[p_index + 1][0], points[p_index + 1][1], 
                  wind_matrix=wind_matrix, rain_matrix=rain_matrix, distance=dis, wind_threshold=wind_threshold[p_index], 
                  rain_threshold=rain_threshold[p_index])
        tmp_path = ant.has_shortest_path()
        cost_time = 2 * (len(tmp_path) - 1)
        if tmp_path:
            path = path + tmp_path[1:]
            dis += cost_time
            print ('path {}: cost {} min'.format(p_index + 1, cost_time))
        else:
            print ('failed in path between {}, {}'.format(points[p_index], points[p_index + 1]))
            print ('please retune the parameters of this path and rerun the code')
            return False
        
    print ('reach {}, cost {}min'.format(points[-1], dis))
    return path

# %% [markdown]
# # 3. set some paramters to guide the Ant find the path we want
#
# ### Actually, we will start a new ipython notebook for every new path in this competition, which is easier to analyze the result.
#
# ### In this notebook, we combined all the parameters in one notebook, to make sure the reader can get the all the paths as fast as possible.
#
# ### The parameter tuning process is the most tiring part of our algorithm, you can skip this step and just run the code. We have two ways to find the guide points. One is automatic and the other is manual.
#
# ### See the PointsFinde.py file to know the automatic way
#
# ### See the django project to know the manual way
#
# ### Both of them is fast and convenient once you get the idea of what's going on behind these codes.

# %% [markdown]
# ### the parameters are stored in json format, so you don't need to find the guide points yourself, each path in each day has different parameters, for example:
#
# 'day10path1': {
#
#      'guide_points': [[137, 244], [139, 234]],
#       'rain_matrix': 'rain_matrix_xgb.pickle',
#       'rain_threshold': [0.2, 2.0, 2.0],
#       'stay_time': [10, 0, 0, 0],
#       'wind_matrix': 'wind_matrix_lgb.pickle',
#       'wind_threshold': [9.7, 9.0, 8.0]
# }
#
# The guide points in this path is (137, 244) and (139, 234).
#
# the used rain map is rain_matrix_xgb.pickle
#
# the rain threshold between start point and (137, 244) is 0.2, the rain threshold between (137, 244) and (139, 234) is 2.0,
# the rain threshold between (139, 234) and target point is 2.0,
#
# start at 10min, and does not stay at any other point
#
# the used wind map is wind_matrix_lgb.pickle
#
# the wind threshold between start point and (137, 244) is 9.7, the wind threshold between (137, 244) and (139, 234) is 9.0,
# the wind threshold between (139, 234) and target point is 8.0,

# %%
with open('parameters.json', 'r') as f:
    params = json.load(f)
params
# Out:
# {'day10path1': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [10]},
#  'day10path10': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.0],
#   'stay_time': [400, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [9.0]},
#  'day10path2': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [90, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [10]},
#  'day10path3': {'guide_points': [[137, 244], [139, 234]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [0.2, 2.0, 2.0],
#   'stay_time': [10, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [9.7, 9.0, 8.0]},
#  'day10path4': {'guide_points': [[230, 242], [233, 239]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [2.5, 4, 13],
#   'stay_time': [70, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11, 15, 15]},
#  'day10path5': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.1],
#   'stay_time': [290, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [9.8]},
#  'day10path6': {'guide_points': [[361, 266], [359, 209], [359, 208]],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [2.0, 3.0, 3.5, 3.5],
#   'stay_time': [20, 0, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.8, 9.0, 11, 12]},
#  'day10path7': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.5],
#   'stay_time': [320, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [10]},
#  'day10path8': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [2.0],
#   'stay_time': [30, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.8]},
#  'day10path9': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.0],
#   'stay_time': [54, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [9.3]},
#  'day6path1': {'guide_points': [[109, 203]],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [1.5, 1.3],
#   'stay_time': [496, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [13, 12.5]},
#  'day6path10': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [852, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.8]},
#  'day6path2': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [1.0],
#   'stay_time': [394, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [13.2]},
#  'day6path3': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.8],
#   'stay_time': [870, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.3]},
#  'day6path4': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.2],
#   'stay_time': [688, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [10.3]},
#  'day6path5': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.2],
#   'stay_time': [606, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.5]},
#  'day6path6': {'guide_points': [[210, 378], [325, 259], [334, 206]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [2, 2, 2, 2],
#   'stay_time': [0, 0, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb_cv.pickle',
#   'wind_threshold': [13.9, 13.7, 13.5, 14.6]},
#  'day6path7': {'guide_points': [[152, 356], [214, 335], [218, 316]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [1.4, 1.5, 2.0, 2.0],
#   'stay_time': [138, 6, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_xgb.pickle',
#   'wind_threshold': [11.7, 11.8, 13.4, 14.8]},
#  'day6path8': {'guide_points': [[206, 339]],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [1.3, 1.3],
#   'stay_time': [148, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [13.0, 12.9]},
#  'day6path9': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.7],
#   'stay_time': [810, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [9]},
#  'day7path1': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [2.3],
#   'stay_time': [292, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.9]},
#  'day7path10': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.2],
#   'stay_time': [816, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11]},
#  'day7path2': {'guide_points': [[145, 328]],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.3, 0.3],
#   'stay_time': [634, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.7, 12.9]},
#  'day7path3': {'guide_points': [[149, 302], [148, 246]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [0.1, 2.0, 2.0],
#   'stay_time': [58, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [14, 14.3, 14.3]},
#  'day7path4': {'guide_points': [[146, 259]],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [0.1, 3.3],
#   'stay_time': [42, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [14.5, 13.9]},
#  'day7path5': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.2],
#   'stay_time': [610, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.4]},
#  'day7path6': {'guide_points': [[156, 326],
#    [303, 316],
#    [359, 228],
#    [358, 208]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [2.1, 2.0, 1.0, 2.3, 4.0],
#   'stay_time': [30, 0, 0, 0, 2, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [14.7, 14.3, 12, 10.9, 10.9]},
#  'day7path7': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.0],
#   'stay_time': [454, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.4]},
#  'day7path8': {'guide_points': [[245, 306],
#    [264, 295],
#    [363, 243],
#    [422, 266]],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [2, 2, 2, 2, 2],
#   'stay_time': [272, 0, 0, 0, 10, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [13, 13, 13, 12, 12]},
#  'day7path9': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.0],
#   'stay_time': [650, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.8]},
#  'day8path1': {'guide_points': [[104, 204]],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [1.0, 1.0],
#   'stay_time': [708, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [10, 9]},
#  'day8path10': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [792, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [9]},
#  'day8path2': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [846, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.8]},
#  'day8path3': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [830, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.8]},
#  'day8path4': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [672, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.8]},
#  'day8path5': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [574, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.5]},
#  'day8path6': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [384, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.4]},
#  'day8path7': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [430, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.7]},
#  'day8path8': {'guide_points': [[268, 231]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [0.5, 0.5],
#   'stay_time': [240, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [13.1, 13.5]},
#  'day8path9': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [918, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [9]},
#  'day9path1': {'guide_points': [[115, 194]],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [4.0, 4.0],
#   'stay_time': [10, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [18.0, 19.7]},
#  'day9path10': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [576, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [11.5]},
#  'day9path2': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [2.3],
#   'stay_time': [878, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [13.0]},
#  'day9path3': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [2.3],
#   'stay_time': [46, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.7]},
#  'day9path4': {'guide_points': [[185, 326], [222, 250]],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [2.3, 2, 2],
#   'stay_time': [400, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12, 12.5, 12]},
#  'day9path5': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_lgb.pickle',
#   'rain_threshold': [2.8],
#   'stay_time': [280, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [12.5]},
#  'day9path6': {'guide_points': [[208, 340]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [1.0, 2.0],
#   'stay_time': [160, 0, 0],
#   'wind_matrix': 'wind_matrix_xgb.pickle',
#   'wind_threshold': [12.9, 14.3]},
#  'day9path7': {'guide_points': [[190, 328],
#    [194, 358],
#    [223, 335],
#    [249, 301],
#    [251, 271],
#    [263, 217]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [1.0, 2.0, 2.0, 2.0, 3.6, 4, 2.6],
#   'stay_time': [176, 0, 0, 0, 0, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_xgb.pickle',
#   'wind_threshold': [11, 11, 14.3, 14.3, 14.3, 14.3, 14.6]},
#  'day9path8': {'guide_points': [[274, 302],
#    [313, 283],
#    [367, 289],
#    [420, 281]],
#   'rain_matrix': 'rain_matrix_lgb_time.pickle',
#   'rain_threshold': [2.4, 2.8, 2.8, 2, 2],
#   'stay_time': [268, 0, 0, 0, 0, 0],
#   'wind_matrix': 'wind_matrix_xgb.pickle',
#   'wind_threshold': [12.1, 12.3, 12.7, 11.5, 12]},
#  'day9path9': {'guide_points': [],
#   'rain_matrix': 'rain_matrix_mean.pickle',
#   'rain_threshold': [0.5],
#   'stay_time': [890, 0],
#   'wind_matrix': 'wind_matrix_lgb.pickle',
#   'wind_threshold': [13.0]}}

# %% [markdown]
# # 4. Run the code to find the path we want
#
# ### Because the map generated in diffenrent devices will be slightly different, so the path generated will be different. But we are sure most of them are still safe.
#
# ### we set the wind threshold and rain threshold really really low to ensure its a safe path, so you may fail in some paths in different maps. It's normal and okay just release the threshold a little bit, and run again.
#
# ### you can change the threshold in the json file directly or modify and run the annoted code
#
# ### Or you can run the codes on the map we generated with the same codes we offered
# ### We stored the map at https://pan.baidu.com/s/1i7cS041
#
# ### 我们将风速和降雨量的阈值设置的非常小，以确保路径尽可能的安全。但这是在我们的地图上所设置的参数，在不同机子上跑出来的地图是不一样的，也就是用这组参数在其它机子上跑出来的地图上无法找到相同的路径（耗时相同且安全的路径有很多）。
#
# ### 比如：在我们机子上跑出来的地图在某条路径上的最大风速为9.8，我们就将阈值掐到了10.0。此时，若在另一幅地图上，该路径的最大风速变成了10.1，这样就走不通了。所以，这个时候就要适当地提高一下风速的阈值，比如改到10.5。
#
# ### 这些参数要根据不同的地图作调整，我们无法保证这组参数适用于其它机子跑出来的地图上。需要逐条修改。
#
# ### 另一个方便的方法就是直接用我们的机子上跑出来的地图来跑下面的程序。地图是用相同的方法跑出来的。我们已经将地图上传到了百度网盘上（https://pan.baidu.com/s/1i7cS041）

# %%
# change the day and path to the one you want, make sure the length of the threshold is the same as before
# params['day6path1']['wind_threshold'] = [15.0, 15.0]
# params['day6path1']['rain_threshold'] = [4.0, 4.0]

# %%
# get city data
city_data = pd.read_csv('../dataset/CityData.csv')

# get start position
start_x, start_y = city_data['xid'][0], city_data['yid'][0]

count = 0
for day in range(6, 11, 1):
    for tar_id in range(1, 11, 1):
        # get target position
        tar_x, tar_y = city_data['xid'][tar_id], city_data['yid'][tar_id]
        
        s = 'day' + str(day) + 'path' + str(tar_id)
        dir_path = '../dataset/day' + str(day)
        
        # get wind matrix and rain matrix
        wind_file = os.path.join(dir_path, params[s]["wind_matrix"])
        rain_file = os.path.join(dir_path, params[s]["rain_matrix"])
        with open(wind_file, 'rb') as f:
            wind_matrix = pickle.load(f)
        with open(rain_file, 'rb') as f:
            rain_matrix = pickle.load(f)
        
        print ('start {}'.format(s))
        points = [(start_x,start_y)] + params[s]["guide_points"] + [(tar_x, tar_y)]
        stay_time = params[s]["stay_time"]
        wind_threshold = params[s]["wind_threshold"]
        rain_threshold = params[s]["rain_threshold"]
        path = get_path(points, stay_time, wind_matrix, rain_matrix, wind_threshold, rain_threshold)
        if path:
            count += 1
            with open('../dataset/result/' + s + '.pickle', 'wb') as f:
                pickle.dump(path, f, protocol=2)
        print ('\n')
print ('There are {}/50 paths generated'.format(count))
# Out:
# start day6path1
# point (142, 328): stay for 496 min
# path 1: cost 316 min
# point [109, 203]: stay for 0 min
# path 2: cost 50 min
# reach (84, 203), cost 862min
#
#
# start day6path2
# point (142, 328): stay for 394 min
# path 1: cost 200 min
# reach (199, 371), cost 594min
#
#
# start day6path3
# point (142, 328): stay for 870 min
# path 1: cost 192 min
# reach (140, 234), cost 1062min
#
#
# start day6path4
# point (142, 328): stay for 688 min
# path 1: cost 362 min
# reach (236, 241), cost 1050min
#
#
# start day6path5
# point (142, 328): stay for 606 min
# path 1: cost 440 min
# reach (315, 281), cost 1046min
#
#
# start day6path6
# point (142, 328): stay for 0 min
# path 1: cost 236 min
# point [210, 378]: stay for 0 min
# path 2: cost 468 min
# point [325, 259]: stay for 0 min
# path 3: cost 124 min
# point [334, 206]: stay for 0 min
# path 4: cost 50 min
# reach (358, 207), cost 878min
#
#
# start day6path7
# point (142, 328): stay for 138 min
# path 1: cost 76 min
# point [152, 356]: stay for 6 min
# path 2: cost 166 min
# point [214, 335]: stay for 0 min
# path 3: cost 46 min
# point [218, 316]: stay for 0 min
# path 4: cost 448 min
# reach (363, 237), cost 880min
#
#
# start day6path8
# point (142, 328): stay for 148 min
# path 1: cost 150 min
# point [206, 339]: stay for 0 min
# path 2: cost 580 min
# reach (423, 266), cost 878min
#
#
# start day6path9
# point (142, 328): stay for 810 min
# path 1: cost 128 min
# reach (125, 375), cost 938min
#
#
# start day6path10
# point (142, 328): stay for 852 min
# path 1: cost 202 min
# reach (189, 274), cost 1054min
#
#
# start day7path1
# point (142, 328): stay for 292 min
# path 1: cost 366 min
# reach (84, 203), cost 658min
#
#
# start day7path2
# point (142, 328): stay for 634 min
# path 1: cost 6 min
# point [145, 328]: stay for 0 min
# path 2: cost 194 min
# reach (199, 371), cost 834min
#
#
# start day7path3
# point (142, 328): stay for 58 min
# path 1: cost 66 min
# point [149, 302]: stay for 0 min
# path 2: cost 114 min
# point [148, 246]: stay for 0 min
# path 3: cost 40 min
# reach (140, 234), cost 278min
#
#
# start day7path4
# point (142, 328): stay for 42 min
# path 1: cost 146 min
# point [146, 259]: stay for 0 min
# path 2: cost 216 min
# reach (236, 241), cost 404min
#
#
# start day7path5
# point (142, 328): stay for 610 min
# path 1: cost 440 min
# reach (315, 281), cost 1050min
#
#
# start day7path6
# point (142, 328): stay for 30 min
# path 1: cost 32 min
# point [156, 326]: stay for 0 min
# path 2: cost 314 min
# point [303, 316]: stay for 0 min
# path 3: cost 288 min
# point [359, 228]: stay for 0 min
# path 4: cost 42 min
# point [358, 208]: stay for 2 min
# path 5: cost 2 min
# reach (358, 207), cost 710min
#
#
# start day7path7
# point (142, 328): stay for 454 min
# path 1: cost 624 min
# reach (363, 237), cost 1078min
#
#
# start day7path8
# point (142, 328): stay for 272 min
# path 1: cost 250 min
# point [245, 306]: stay for 0 min
# path 2: cost 60 min
# point [264, 295]: stay for 0 min
# path 3: cost 302 min
# point [363, 243]: stay for 0 min
# path 4: cost 164 min
# point [422, 266]: stay for 10 min
# path 5: cost 2 min
# reach (423, 266), cost 1060min
#
#
# start day7path9
# point (142, 328): stay for 650 min
# path 1: cost 128 min
# reach (125, 375), cost 778min
#
#
# start day7path10
# point (142, 328): stay for 816 min
# path 1: cost 202 min
# reach (189, 274), cost 1018min
#
#
# start day8path1
# point (142, 328): stay for 708 min
# path 1: cost 324 min
# point [104, 204]: stay for 0 min
# path 2: cost 42 min
# reach (84, 203), cost 1074min
#
#
# start day8path2
# point (142, 328): stay for 846 min
# path 1: cost 200 min
# reach (199, 371), cost 1046min
#
#
# start day8path3
# point (142, 328): stay for 830 min
# path 1: cost 192 min
# reach (140, 234), cost 1022min
#
#
# start day8path4
# point (142, 328): stay for 672 min
# path 1: cost 362 min
# reach (236, 241), cost 1034min
#
#
# start day8path5
# point (142, 328): stay for 574 min
# path 1: cost 440 min
# reach (315, 281), cost 1014min
#
#
# start day8path6
# point (142, 328): stay for 384 min
# path 1: cost 674 min
# reach (358, 207), cost 1058min
#
#
# start day8path7
# point (142, 328): stay for 430 min
# path 1: cost 624 min
# reach (363, 237), cost 1054min
#
#
# start day8path8
# point (142, 328): stay for 240 min
# path 1: cost 446 min
# point [268, 231]: stay for 0 min
# path 2: cost 380 min
# reach (423, 266), cost 1066min
#
#
# start day8path9
# point (142, 328): stay for 918 min
# path 1: cost 128 min
# reach (125, 375), cost 1046min
#
#
# start day8path10
# point (142, 328): stay for 792 min
# path 1: cost 202 min
# reach (189, 274), cost 994min
#
#
# start day9path1
# point (142, 328): stay for 10 min
# path 1: cost 322 min
# point [115, 194]: stay for 0 min
# path 2: cost 80 min
# reach (84, 203), cost 412min
#
#
# start day9path2
# point (142, 328): stay for 878 min
# path 1: cost 200 min
# reach (199, 371), cost 1078min
#
#
# start day9path3
# point (142, 328): stay for 46 min
# path 1: cost 192 min
# reach (140, 234), cost 238min
#
#
# start day9path4
# point (142, 328): stay for 400 min
# path 1: cost 90 min
# point [185, 326]: stay for 0 min
# path 2: cost 226 min
# point [222, 250]: stay for 0 min
# path 3: cost 46 min
# reach (236, 241), cost 762min
#
#
# start day9path5
# point (142, 328): stay for 280 min
# path 1: cost 440 min
# reach (315, 281), cost 720min
#
#
# start day9path6
# point (142, 328): stay for 160 min
# path 1: cost 156 min
# point [208, 340]: stay for 0 min
# path 2: cost 566 min
# reach (358, 207), cost 882min
#
#
# start day9path7
# point (142, 328): stay for 176 min
# path 1: cost 96 min
# point [190, 328]: stay for 0 min
# path 2: cost 68 min
# point [194, 358]: stay for 0 min
# path 3: cost 104 min
# point [223, 335]: stay for 0 min
# path 4: cost 120 min
# point [249, 301]: stay for 0 min
# path 5: cost 64 min
# point [251, 271]: stay for 0 min
# path 6: cost 132 min
# point [263, 217]: stay for 0 min
# path 7: cost 240 min
# reach (363, 237), cost 1000min
#
#
# start day9path8
# point (142, 328): stay for 268 min
# path 1: cost 316 min
# point [274, 302]: stay for 0 min
# path 2: cost 116 min
# point [313, 283]: stay for 0 min
# path 3: cost 120 min
# point [367, 289]: stay for 0 min
# path 4: cost 122 min
# point [420, 281]: stay for 0 min
# path 5: cost 36 min
# reach (423, 266), cost 978min
#
#
# start day9path9
# point (142, 328): stay for 890 min
# path 1: cost 128 min
# reach (125, 375), cost 1018min
#
#
# start day9path10
# point (142, 328): stay for 576 min
# path 1: cost 202 min
# reach (189, 274), cost 778min
#
#
# start day10path1
# point (142, 328): stay for 0 min
# path 1: cost 366 min
# reach (84, 203), cost 366min
#
#
# start day10path2
# point (142, 328): stay for 90 min
# path 1: cost 200 min
# reach (199, 371), cost 290min
#
#
# start day10path3
# point (142, 328): stay for 10 min
# path 1: cost 178 min
# point [137, 244]: stay for 0 min
# path 2: cost 24 min
# point [139, 234]: stay for 0 min
# path 3: cost 2 min
# reach (140, 234), cost 214min
#
#
# start day10path4
# point (142, 328): stay for 70 min
# path 1: cost 348 min
# point [230, 242]: stay for 0 min
# path 2: cost 12 min
# point [233, 239]: stay for 0 min
# path 3: cost 10 min
# reach (236, 241), cost 440min
#
#
# start day10path5
# point (142, 328): stay for 290 min
# path 1: cost 440 min
# reach (315, 281), cost 730min
#
#
# start day10path6
# point (142, 328): stay for 20 min
# path 1: cost 562 min
# point [361, 266]: stay for 0 min
# path 2: cost 118 min
# point [359, 209]: stay for 0 min
# path 3: cost 2 min
# point [359, 208]: stay for 0 min
# path 4: cost 4 min
# reach (358, 207), cost 706min
#
#
# start day10path7
# point (142, 328): stay for 320 min
# path 1: cost 624 min
# reach (363, 237), cost 944min
#
#
# start day10path8
# point (142, 328): stay for 30 min
# path 1: cost 686 min
# reach (423, 266), cost 716min
#
#
# start day10path9
# point (142, 328): stay for 54 min
# path 1: cost 128 min
# reach (125, 375), cost 182min
#
#
# start day10path10
# point (142, 328): stay for 400 min
# path 1: cost 202 min
# reach (189, 274), cost 602min
#
#
# There are 50/50 paths generated
